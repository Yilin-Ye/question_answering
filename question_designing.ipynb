# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', None)

# %%
def assign_questions(num):
    from random import sample
    encounter_list = [436, 236, 337, 791, 219, 574, 10, 555, 776, 262, 987, 352, 824, 602, 849, 198, 195, 
                      419, 286, 909, 107, 167, 169, 254, 650, 943, 838, 223, 685, 591, 277, 832, 283, 320, 
                      502, 905, 489, 874, 63, 425, 772, 991, 76, 878, 984, 990, 106, 451, 999, 748,627,196,197,
                      437, 212, 255, 666, 777, 888, 555, 323, 997, 199, 233]
    question_list = ['when was the earlist time?',"when was the latest time?","What is the highest heart rate?",
                'what is the lowest pulse rate?','What is the highest SpO2?', 'what is the lowest SpO2?',
                "What's the highest respiration rate?", "What's the lowest respiration rate?", 
                 "when is the last time measured the blood pressure?", 'when is the earlest measured the blood pressure?',
                "What is the highest pulse rate?", "What is the lowest heart rate?", 'what is the lowest MAP (mmHg)?',
                'what is the highest MAP (mmHg)?', 'what is the lowest temperature?', 'what is the highest temperature?',
                "When was the highest heart rate?", 'when was the lowest pulse rate?', 'when was the highest SpO2?',
                'when was the lowest SpO2?', "when was the highest respiration rate?", "When was the lowest respiration rate?",
                "When was the highest pulse rate?", "when was the lowest heart rate?", 'when the lowest MAP (mmHg)?',
                'when was the highest MAP (mmHg)?', 'when was the lowest temperature?', 'when was the highest temperature?',
                     
                   'when was the first time?',"when was the most recent time?",
                     'what was the first time?',"what was the most recent time?",
                     "What is the biggest heart rate?", "What is the greatest heart rate?",
                     "What is the smallest heart rate?", 'what is the smallest pulse rate?',
                     'What is the biggest SpO2?', 'what is the smallest SpO2?',
                'what is the least pulse rate?','What is the greatest SpO2?', 
                     'what is the least SpO2?', "What's the greatest respiration rate?", 
                     "What's the least respiration rate?", "What's the biggest respiration rate?", 
                     "What's the minimum respiration rate?",  "What's the maximum respiration rate?", 
                     "What's the maximum respiration rate?", "when is the most recent time measured the blood pressure?", 
                     'when is the first measured the blood pressure?', "What is the max pulse rate?", 
                     "What is the least heart rate?", 'what is the smallest MAP (mmHg)?',        
                'what is the greatest MAP (mmHg)?', 'what is the minimum temperature?', 
                     'what is the biggest temperature?', "What was the highest heart rate time?", 
                     'what was the least pulse rate time?',  'what was the greatest SpO2 time?',
                "What was the maximum heart rate time?", 'what was the lowest pulse rate time?', 
                     'what was the max SpO2 time?', 'what was the least SpO2 time?', 
                     "what was the highest respiration rate time?",  "What was the lowest respiration rate time?",
                "What was the greatest pulse rate time?", "what was the smallest heart rate time?", 
                     'what was the lowest MAP (mmHg) time?', 'when was the greatest MAP (mmHg)?', 
                     'when was the least temperature?', 'when was the maximal temperature?']
    
    df = pd.DataFrame(columns=['question', 'table_file', 'answer_coordinates', 'answer_text', 'float_answer'])
    for encounter in encounter_list:
        
        xx = pd.read_csv(f'dataset/{encounter}.csv')
        
        location = f'dataset/{encounter}.csv'
        
        questions = sample(question_list,num)
        for question in questions:
            if question == "when was the earlist time?":
                q = [[question],location,[[(0,0)]],[[xx.iloc[0,0]]],np.nan]
            elif question == "when was the first time?":
                q = [[question],location,[[(0,0)]],[[xx.iloc[0,0]]],np.nan]
            elif question == "what was the first time?":
                q = [[question],location,[[(0,0)]],[[xx.iloc[0,0]]],np.nan]
                

            elif question == "when was the latest time?":
                locations = len(xx)-1
                q = [[question],location,[[(locations,0)]],[[xx.iloc[locations-1,0]]],np.nan]
            elif question == "when was the most recent time?":
                locations = len(xx)-1
                q = [[question],location,[[(locations,0)]],[[xx.iloc[locations-1,0]]],np.nan]
            elif question == "what was the most recent time?":
                locations = len(xx)-1
                q = [[question],location,[[(locations,0)]],[[xx.iloc[locations-1,0]]],np.nan]
            
            

            elif question == "What is the highest heart rate?":
                highest = max(xx['Heart Rate'])
                row_number = xx[xx['Heart Rate']==highest].index.values
                nums_rows = len(row_number)
                q = [[question],location,[[(i,3) for i in row_number]],[[highest]],highest] 
            elif question == "What is the biggest heart rate?":
                highest = max(xx['Heart Rate'])
                row_number = xx[xx['Heart Rate']==highest].index.values
                nums_rows = len(row_number)
                q = [[question],location,[[(i,3) for i in row_number]],[[highest]],highest]
            elif question == "What is the greatest heart rate?":
                highest = max(xx['Heart Rate'])
                row_number = xx[xx['Heart Rate']==highest].index.values
                nums_rows = len(row_number)
                q = [[question],location,[[(i,3) for i in row_number]],[[highest]],highest]
                
                
                
            elif question == 'what is the lowest pulse rate?':
                lowest = min(xx['Pulse'])
                row_number = xx[xx['Pulse']==lowest].index.values
                nums_rows = len(row_number)
                q = [[question],location,[[(i,6) for i in row_number]],[[lowest]],lowest] 
            elif question == 'what is the least pulse rate?':
                lowest = min(xx['Pulse'])
                row_number = xx[xx['Pulse']==lowest].index.values
                nums_rows = len(row_number)
                q = [[question],location,[[(i,6) for i in row_number]],[[lowest]],lowest]
                
                

            elif question == 'What is the highest SpO2?':
                highest = max(xx['SpO2'])
                row_number = xx[xx['SpO2']==highest].index.values
                nums_rows = len(row_number)
                q = [[question],location,[[(i,8) for i in row_number]],[[highest]],highest] 
            elif question == 'What is the biggest SpO2?':
                highest = max(xx['SpO2'])
                row_number = xx[xx['SpO2']==highest].index.values
                nums_rows = len(row_number)
                q = [[question],location,[[(i,8) for i in row_number]],[[highest]],highest]
            elif question == 'What is the greatest SpO2?':
                highest = max(xx['SpO2'])
                row_number = xx[xx['SpO2']==highest].index.values
                nums_rows = len(row_number)
                q = [[question],location,[[(i,8) for i in row_number]],[[highest]],highest]
                
                

            elif question == 'what is the lowest SpO2?':
                lowest = min(xx['SpO2'])
                row_number = xx[xx['SpO2']==lowest].index.values
                nums_rows = len(row_number)
                q = [[question],location,[[(i,8) for i in row_number]],[[lowest]],lowest]
            elif question == 'what is the smallest SpO2?':
                lowest = min(xx['SpO2'])
                row_number = xx[xx['SpO2']==lowest].index.values
                nums_rows = len(row_number)
                q = [[question],location,[[(i,8) for i in row_number]],[[lowest]],lowest]
            elif question == 'what is the least SpO2?':
                lowest = min(xx['SpO2'])
                row_number = xx[xx['SpO2']==lowest].index.values
                nums_rows = len(row_number)
                q = [[question],location,[[(i,8) for i in row_number]],[[lowest]],lowest]
                


            elif question == "What's the highest respiration rate?":
                highest = max(xx['Resp'])
                row_number = xx[xx['Resp']==highest].index.values
                nums_rows = len(row_number)
                q = [[question], location, [[(i,7) for i in row_number]], [[highest]],highest]
            elif question == "What's the greatest respiration rate?":
                highest = max(xx['Resp'])
                row_number = xx[xx['Resp']==highest].index.values
                nums_rows = len(row_number)
                q = [[question], location, [[(i,7) for i in row_number]], [[highest]],highest] 
            elif question == "What's the biggest respiration rate?":
                highest = max(xx['Resp'])
                row_number = xx[xx['Resp']==highest].index.values
                nums_rows = len(row_number)
                q = [[question], location, [[(i,7) for i in row_number]], [[highest]],highest]
            elif question == "What's the maximum respiration rate?":
                highest = max(xx['Resp'])
                row_number = xx[xx['Resp']==highest].index.values
                nums_rows = len(row_number)
                q = [[question], location, [[(i,7) for i in row_number]], [[highest]],highest]
                
                

            elif question == "What's the lowest respiration rate?":
                lowest = min(xx['Resp'])
                row_number = xx[xx['Resp']==lowest].index.values
                nums_rows = len(row_number)
                q = [[question], location, [[(i,7) for i in row_number]], [[lowest]],lowest] 
            elif question == "What's the least respiration rate?":
                lowest = min(xx['Resp'])
                row_number = xx[xx['Resp']==lowest].index.values
                nums_rows = len(row_number)
                q = [[question], location, [[(i,7) for i in row_number]], [[lowest]],lowest]
            elif question == "What's the minimum respiration rate?":
                lowest = min(xx['Resp'])
                row_number = xx[xx['Resp']==lowest].index.values
                nums_rows = len(row_number)
                q = [[question], location, [[(i,7) for i in row_number]], [[lowest]],lowest]
                
                
                
            elif question == 'when is the earlest measured the blood pressure?':
                q = [[question], location, [[(0,0)]], [[xx.iloc[0,1]]],np.nan]  
            elif question == 'when is the first measured the blood pressure?':
                q = [[question], location, [[(0,0)]], [[xx.iloc[0,1]]],np.nan]


            elif question == "when is the last time measured the blood pressure?":
                q = [[question],location,[[(len(xx)-1,0)]],[[xx.iloc[len(xx)-1,1]]],np.nan]    
            elif question == "when is the most recent time measured the blood pressure?":
                q = [[question],location,[[(len(xx)-1,0)]],[[xx.iloc[len(xx)-1,1]]],np.nan] 
                


            elif question == "What is the highest pulse rate?":
                highest = max(xx['Pulse'])
                row_number = xx[xx['Pulse']==highest].index.values
                nums_rows = len(row_number)
                q = [[question],location,[[(i,6) for i in row_number]],[[highest]],highest] 
            elif question == "What is the max pulse rate?":
                highest = max(xx['Pulse'])
                row_number = xx[xx['Pulse']==highest].index.values
                nums_rows = len(row_number)
                q = [[question],location,[[(i,6) for i in row_number]],[[highest]],highest]
                
                
                
            elif question == "what is the smallest pulse rate?":
                highest = max(xx['Pulse'])
                row_number = xx[xx['Pulse']==highest].index.values
                nums_rows = len(row_number)
                q = [[question],location,[[(i,6) for i in row_number]],[[highest]],highest]


                
            elif question == "What is the lowest heart rate?":
                lowest = min(xx['Heart Rate'])
                row_number = xx[xx['Heart Rate']==lowest].index.values
                nums_rows = len(row_number)
                q = [[question],location,[[(i,3) for i in row_number]],[[lowest]],lowest] 
            elif question == "What is the smallest heart rate?":
                lowest = min(xx['Heart Rate'])
                row_number = xx[xx['Heart Rate']==lowest].index.values
                nums_rows = len(row_number)
                q = [[question],location,[[(i,3) for i in row_number]],[[lowest]],lowest]
            elif question == "What is the least heart rate?":
                lowest = min(xx['Heart Rate'])
                row_number = xx[xx['Heart Rate']==lowest].index.values
                nums_rows = len(row_number)
                q = [[question],location,[[(i,3) for i in row_number]],[[lowest]],lowest]
                
                
                
            elif question == 'what is the lowest MAP (mmHg)?':
                lowest = min(xx['MAP (mmHg)'])
                row_number = xx[xx['MAP (mmHg)']==lowest].index.values
                nums_rows = len(row_number)
                q = [[question],location,[[(i,5) for i in row_number]],[[lowest]],lowest]  
            elif question == 'what is the smallest MAP (mmHg)?':
                lowest = min(xx['MAP (mmHg)'])
                row_number = xx[xx['MAP (mmHg)']==lowest].index.values
                nums_rows = len(row_number)
                q = [[question],location,[[(i,5) for i in row_number]],[[lowest]],lowest]
                


            elif question == 'what is the highest MAP (mmHg)?':
                highest = max(xx['MAP (mmHg)'])
                row_number = xx[xx['MAP (mmHg)']==highest].index.values
                nums_rows = len(row_number)
                q = [[question], location, [[(i,5) for i in row_number]], [[highest]], highest]   
            elif question == 'what is the greatest MAP (mmHg)?':
                highest = max(xx['MAP (mmHg)'])
                row_number = xx[xx['MAP (mmHg)']==highest].index.values
                nums_rows = len(row_number)
                q = [[question], location, [[(i,5) for i in row_number]], [[highest]], highest]
                
                

            elif question == 'what is the lowest temperature?':
                lowest = min(xx['Temp'])
                row_number = xx[xx['Temp']==lowest].index.values
                nums_rows = len(row_number)
                q = [[question], location, [[(i,9) for i in row_number]], [[lowest]],lowest]
            elif question == 'what is the minimum temperature?':
                lowest = min(xx['Temp'])
                row_number = xx[xx['Temp']==lowest].index.values
                nums_rows = len(row_number)
                q = [[question], location, [[(i,9) for i in row_number]], [[lowest]],lowest]
                
                

            elif question == 'what is the highest temperature?':
                highest = max(xx['Temp'])
                row_number = xx[xx['Temp']==highest].index.values
                nums_rows = len(row_number)
                q = [[question], location, [[(i,9) for i in row_number]], [[highest]],highest] 
            elif question == 'what is the biggest temperature?':
                highest = max(xx['Temp'])
                row_number = xx[xx['Temp']==highest].index.values
                nums_rows = len(row_number)
                q = [[question], location, [[(i,9) for i in row_number]], [[highest]],highest] 
                
                

            elif question == "When was the highest heart rate?":
                highest = max(xx['Heart Rate'])
                row_number = xx[xx['Heart Rate']==highest].index.values
                nums_rows = len(row_number)
                q = [[question],location,[[(i,0) for i in row_number]],[[xx.iloc[i,0] for i in row_number]],np.nan]
            elif question == "What was the highest heart rate time?":
                highest = max(xx['Heart Rate'])
                row_number = xx[xx['Heart Rate']==highest].index.values
                nums_rows = len(row_number)
                q = [[question],location,[[(i,0) for i in row_number]],[[xx.iloc[i,0] for i in row_number]],np.nan]
            elif question == "What was the maximum heart rate time?":
                highest = max(xx['Heart Rate'])
                row_number = xx[xx['Heart Rate']==highest].index.values
                nums_rows = len(row_number)
                q = [[question],location,[[(i,0) for i in row_number]],[[xx.iloc[i,0] for i in row_number]],np.nan]
                
                

            elif question == 'when was the lowest pulse rate?':
                lowest = min(xx['Pulse'])
                row_number = xx[xx['Pulse']==lowest].index.values
                nums_rows = len(row_number)
                q = [[question],location,[[(i,0) for i in row_number]],[[xx.iloc[i,0] for i in row_number]],np.nan] 
            elif question == 'what was the least pulse rate time?':
                lowest = min(xx['Pulse'])
                row_number = xx[xx['Pulse']==lowest].index.values
                nums_rows = len(row_number)
                q = [[question],location,[[(i,0) for i in row_number]],[[xx.iloc[i,0] for i in row_number]],np.nan]
            elif question == 'what was the lowest pulse rate time?':
                lowest = min(xx['Pulse'])
                row_number = xx[xx['Pulse']==lowest].index.values
                nums_rows = len(row_number)
                q = [[question],location,[[(i,0) for i in row_number]],[[xx.iloc[i,0] for i in row_number]],np.nan]
                


            elif question == 'when was the highest SpO2?':
                highest = max(xx['SpO2'])
                row_number = xx[xx['SpO2']==highest].index.values
                nums_rows = len(row_number)
                q = [[question],location,[[(i,0) for i in row_number]],[[xx.iloc[i,0] for i in row_number]],np.nan]
            elif question == 'what was the greatest SpO2 time?':
                highest = max(xx['SpO2'])
                row_number = xx[xx['SpO2']==highest].index.values
                nums_rows = len(row_number)
                q = [[question],location,[[(i,0) for i in row_number]],[[xx.iloc[i,0] for i in row_number]],np.nan] 
            elif question == 'what was the max SpO2 time?':
                highest = max(xx['SpO2'])
                row_number = xx[xx['SpO2']==highest].index.values
                nums_rows = len(row_number)
                q = [[question],location,[[(i,0) for i in row_number]],[[xx.iloc[i,0] for i in row_number]],np.nan]
                
                

            elif question == 'when was the lowest SpO2?':
                lowest = min(xx['SpO2'])
                row_number = xx[xx['SpO2']==lowest].index.values
                nums_rows = len(row_number)
                q = [[question],location,[[(i,0) for i in row_number]],[[xx.iloc[i,0] for i in row_number]],np.nan] 
            elif question == 'what was the least SpO2 time?':
                lowest = min(xx['SpO2'])
                row_number = xx[xx['SpO2']==lowest].index.values
                nums_rows = len(row_number)
                q = [[question],location,[[(i,0) for i in row_number]],[[xx.iloc[i,0] for i in row_number]],np.nan]
                
                

            elif question == "when was the highest respiration rate?":
                highest = max(xx['Resp'])
                row_number = xx[xx['Resp']==highest].index.values
                nums_rows = len(row_number)
                q = [[question],location,[[(i,0) for i in row_number]],[[xx.iloc[i,0] for i in row_number]],np.nan] 
            elif question == "what was the highest respiration rate time?":
                highest = max(xx['Resp'])
                row_number = xx[xx['Resp']==highest].index.values
                nums_rows = len(row_number)
                q = [[question],location,[[(i,0) for i in row_number]],[[xx.iloc[i,0] for i in row_number]],np.nan]


                
            elif question == "When was the lowest respiration rate?":
                lowest = min(xx['Resp'])
                row_number = xx[xx['Resp']==lowest].index.values
                nums_rows = len(row_number)
                q = [[question],location,[[(i,0) for i in row_number]],[[xx.iloc[i,0] for i in row_number]],np.nan]
            elif question == "What was the lowest respiration rate time?":
                lowest = min(xx['Resp'])
                row_number = xx[xx['Resp']==lowest].index.values
                nums_rows = len(row_number)
                q = [[question],location,[[(i,0) for i in row_number]],[[xx.iloc[i,0] for i in row_number]],np.nan]

                

            elif question == "When was the highest pulse rate?":
                highest = max(xx['Pulse'])
                row_number = xx[xx['Pulse']==highest].index.values
                nums_rows = len(row_number)
                q = [[question],location,[[(i,0) for i in row_number]],[[xx.iloc[i,0] for i in row_number]],np.nan] 
            elif question == "What was the greatest pulse rate time?":
                highest = max(xx['Pulse'])
                row_number = xx[xx['Pulse']==highest].index.values
                nums_rows = len(row_number)
                q = [[question],location,[[(i,0) for i in row_number]],[[xx.iloc[i,0] for i in row_number]],np.nan]
                


            elif question == "when was the lowest heart rate?":
                lowest = min(xx['Heart Rate'])
                row_number = xx[xx['Heart Rate']==lowest].index.values
                nums_rows = len(row_number)
                q = [[question],location,[[(i,0) for i in row_number]],[[xx.iloc[i,0] for i in row_number]],np.nan]
            elif question == "what was the smallest heart rate time?":
                lowest = min(xx['Heart Rate'])
                row_number = xx[xx['Heart Rate']==lowest].index.values
                nums_rows = len(row_number)
                q = [[question],location,[[(i,0) for i in row_number]],[[xx.iloc[i,0] for i in row_number]],np.nan]
                


            elif question == 'when the lowest MAP (mmHg)?':
                lowest = min(xx['MAP (mmHg)'])
                row_number = xx[xx['MAP (mmHg)']==lowest].index.values
                nums_rows = len(row_number)
                q = [[question],location,[[(i,0) for i in row_number]],[[xx.iloc[i,0] for i in row_number]],np.nan]
            elif question == 'what was the lowest MAP (mmHg) time?':
                lowest = min(xx['MAP (mmHg)'])
                row_number = xx[xx['MAP (mmHg)']==lowest].index.values
                nums_rows = len(row_number)
                q = [[question],location,[[(i,0) for i in row_number]],[[xx.iloc[i,0] for i in row_number]],np.nan]
                


            elif question == 'when was the highest MAP (mmHg)?':
                highest = max(xx['MAP (mmHg)'])
                row_number = xx[xx['MAP (mmHg)']==highest].index.values
                nums_rows = len(row_number)
                q = [[question],location,[[(i,0) for i in row_number]],[[xx.iloc[i,0] for i in row_number]],np.nan]
            elif question == 'when was the greatest MAP (mmHg)':
                highest = max(xx['MAP (mmHg)'])
                row_number = xx[xx['MAP (mmHg)']==highest].index.values
                nums_rows = len(row_number)
                q = [[question],location,[[(i,0) for i in row_number]],[[xx.iloc[i,0] for i in row_number]],np.nan]
                


            elif question == 'when was the lowest temperature?':
                lowest = min(xx['Temp'])
                row_number = xx[xx['Temp']==lowest].index.values
                nums_rows = len(row_number)
                q = [[question],location,[[(i,0) for i in row_number]],[[xx.iloc[i,0] for i in row_number]],np.nan] 
            elif question == 'when was the least temperature?':
                lowest = min(xx['Temp'])
                row_number = xx[xx['Temp']==lowest].index.values
                nums_rows = len(row_number)
                q = [[question],location,[[(i,0) for i in row_number]],[[xx.iloc[i,0] for i in row_number]],np.nan] 
                
                


            elif question == 'when was the highest temperature?':
                highest = max(xx['Temp'])
                row_number = xx[xx['Temp']==highest].index.values
                nums_rows = len(row_number)
                q = [[question],location,[[(i,0) for i in row_number]],[[xx.iloc[i,0] for i in row_number]],np.nan]
            elif question == 'when was the maximal temperature?':
                highest = max(xx['Temp'])
                row_number = xx[xx['Temp']==highest].index.values
                nums_rows = len(row_number)
                q = [[question],location,[[(i,0) for i in row_number]],[[xx.iloc[i,0] for i in row_number]],np.nan]
            
            
            
            df.loc[len(df)] = q

    return df
